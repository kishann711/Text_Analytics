# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Load the cleaned data
df = pd.read_csv("../data/processed/cleaned_data.csv")

# Display the first few rows
print(df.head())

# Word Cloud Generation: Visualize the most common words
text = " ".join(df['cleaned_text'])
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
#    id                                            text  \
# 0   1             I love natural language processing!
# 1   2  Data cleaning is essential for good analytics.
# 2   3        Pre-trained embeddings make life easier.
#
#                              cleaned_text
# 0        love natural language processing
# 1  data cleaning essential good analytics
# 2  pretrained embeddings make life easier
